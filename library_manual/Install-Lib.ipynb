# %%
# %pip install numpy
# %pip install pandas
# %pip install nltk
# %pip install scikit-learn
# %pip install transformers
# %pip install PySastrawi
# %pip install datasets
# %pip install wordcloud
# %pip install seaborn
# %pip install confusion-matrix
# %pip install matplotlib
# Out:
# Requirement already satisfied: numpy in d:\projects\emodet-app-new-thesis\env\lib\site-packages (2.2.0)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in d:\projects\emodet-app-new-thesis\env\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from pandas) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: nltk in d:\projects\emodet-app-new-thesis\env\lib\site-packages (3.9.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: click in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in d:\projects\emodet-app-new-thesis\env\lib\site-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.6.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: transformers in d:\projects\emodet-app-new-thesis\env\lib\site-packages (4.47.0)
# Requirement already satisfied: filelock in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from transformers) (0.26.5)
# Requirement already satisfied: numpy>=1.17 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from transformers) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: colorama in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from requests->transformers) (2024.12.14)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: PySastrawi in d:\projects\emodet-app-new-thesis\env\lib\site-packages (1.2.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: datasets in d:\projects\emodet-app-new-thesis\env\lib\site-packages (3.2.0)
# Requirement already satisfied: filelock in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from datasets) (2.2.0)
# Requirement already satisfied: pyarrow>=15.0.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from datasets) (3.11.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from datasets) (0.26.5)
# Requirement already satisfied: packaging in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: colorama in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting wordcloud
#   Using cached wordcloud-1.9.4-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from wordcloud) (2.2.0)
# Requirement already satisfied: pillow in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib->wordcloud) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib->wordcloud) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Using cached wordcloud-1.9.4-cp312-cp312-win_amd64.whl (301 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting seabornNote: you may need to restart the kernel to use updated packages.
#
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from seaborn) (2.2.0)
# Requirement already satisfied: pandas>=1.2 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting confusion-matrix
#   Using cached confusion_matrix-0.1-py3-none-any.whl
# Collecting nose (from confusion-matrix)
#   Using cached nose-1.3.7-py3-none-any.whl.metadata (1.7 kB)
# Using cached nose-1.3.7-py3-none-any.whl (154 kB)
# Installing collected packages: nose, confusion-matrix
# Successfully installed confusion-matrix-0.1 nose-1.3.7
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: matplotlib in d:\projects\emodet-app-new-thesis\env\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install torch
# Out:
# Requirement already satisfied: torch in d:\projects\emodet-app-new-thesis\env\lib\site-packages (2.5.1)
# Requirement already satisfied: filelock in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from torch) (2024.9.0)
# Requirement already satisfied: setuptools in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from torch) (75.6.0)
# Requirement already satisfied: sympy==1.13.1 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\projects\emodet-app-new-thesis\env\lib\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True
