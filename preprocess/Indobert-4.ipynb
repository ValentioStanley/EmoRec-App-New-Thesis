# %% [markdown]
# # indolem/indobertweet-base-uncased

# %%
#https://huggingface.co/indobenchmark/indobert-base-lite-p2
# %pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)

# %%
gpu_info = %nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Dec 11 16:06:25 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# %pip install ntlk
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement ntlk (from versions: none)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for ntlk

# %%
# %pip install PySastrawi
# Out:
# Requirement already satisfied: PySastrawi in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (1.2.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# %pip install datasets
# Out:
# Requirement already satisfied: datasets in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (3.2.0)
# Requirement already satisfied: filelock in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from datasets) (2.1.3)
# Requirement already satisfied: pyarrow>=15.0.0 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from datasets) (3.11.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from datasets) (0.26.5)
# Requirement already satisfied: packaging in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: colorama in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in d:\projects\product-review-data-mining-app-thesis\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification,AutoModel,BertTokenizer,AutoConfig
from transformers import TrainingArguments
from transformers import Trainer
from transformers import pipeline
# from datasets import load_metric
# from datasets import load_dataset
from datasets import Dataset
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np

# %%
#Loading the data train .txt file
# df = pd.read_csv("/content/gdrive/MyDrive/ColabNotebooks/Chatbot/Experimen 3/Data/Dataset/Train/Dataset Tokopedia Review - Train (Semicolon Delimited).txt" , sep=';',encoding= 'unicode_escape')
# df = pd.read_csv("sample_data/PRDECT-ID.csv" , encoding='ISO-8859-1')
df = pd.read_csv('../dataset/PRDECT-ID.csv')
# df.set_index(["labelEmotions","category","reviewText"]).count(level="labelEmotions")
df.set_index(["Emotion","Category","Customer Review"]).value_counts('Emotion')
# Out:
# Emotion
# Happy      1770
# Sadness    1202
# Fear        920
# Love        809
# Anger       699
# Name: count, dtype: int64

# %%
# kamus_alay = pd.read_csv("sample_data/kamusalay.csv" , encoding='ISO-8859-1',header = None)
kamus_alay = pd.read_csv('../dataset/kamusalay.csv', encoding='ISO-8859-1', header = None)
kamus_alay_dict = kamus_alay.set_index(0).to_dict('dict')[1]
kamus_alay_dict
# Out:
# {'anakjakartaasikasik': 'anak jakarta asyik asyik',
#  'pakcikdahtua': 'pak cik sudah tua',
#  'pakcikmudalagi': 'pak cik muda lagi',
#  't3tapjokowi': 'tetap jokowi',
#  '3x': 'tiga kali',
#  'aamiin': 'amin ',
#  'aamiinn': 'amin',
#  'aamin': 'amin',
#  'aammiin': 'amin',
#  'abis': 'habis',
#  'abisin': 'habiskan',
#  'acau': 'kacau',
#  'achok': 'ahok',
#  'ad': 'ada',
#  'adek': 'adik ',
#  'adl': 'adalah',
#  'adlah': 'adalah',
#  'adlh': 'adalah ',
#  'ado': 'ada',
#  'aduhh': 'aduh',
#  'aer': 'air ',
#  'afdol': 'afdal',
#  'agamaataualqur': 'agama alquran',
#  'agm': 'agama',
#  'agma': 'agama',
#  'ahaha': 'haha',
#  'ahahaha': 'haha',
#  'ahehehehe': 'hehe',
#  'ahir': 'akhir',
#  'ahirnya': 'akhirnya',
#  'ahk': 'ahok',
#  'ahlamdulillah': 'alhamdulillah',
#  'ahli2': 'para ahli',
#  'ahlusunnah': 'ahlus sunah',
#  'ahmaddani': 'ahmad dhani',
#  'aho': 'ahok',
#  'ahoax': 'ahok',
#  'ahoaxx': 'ahok',
#  'ahog': 'ahok',
#  'ahokataudjarot': 'ahok djarot',
#  'ahokbebanijokowi': 'ahok beban jokowi',
#  'ahokbtp': 'ahok basuki tjahaja purnama',
#  'ahokditolakwarga': 'ahok ditolak warga',
#  'ahokdjarot': 'ahok djarot',
#  'ahokdjarotterbukti': 'ahok djarot terbukti',
#  'ahokers': 'ahoker',
#  'ahokfighter': 'ahok pejuang',
#  'ahokforpresident': 'ahok for presiden',
#  'ahokisthebest': 'ahok terbaik',
#  'ahokjarot': 'ahok djarot',
#  'ahokk': 'ahok',
#  'ahokmasukbui': 'ahok masuk bui',
#  'ahokmeskipun': 'ahok meskipun',
#  'ahokpositifjadi': 'ahok positif jadi',
#  'ahoksatuputaran': 'ahok satu putaran',
#  'ahoksemangat': 'ahok semangat',
#  'ahoktersangka': 'ahok tersangka',
#  'ahokterzhalimi': 'ahok terzalimi',
#  'ahoktetap': 'ahok tetap',
#  'ahoktidaksendiri': 'ahok tidak sendiri',
#  'ahokUSER': 'ahok',
#  'ahook': 'ahok',
#  'ahox': 'ahok',
#  'aing': 'aku',
#  'airmata': 'air mata',
#  'aiskrim': 'es krim ',
#  'aj': 'saja ',
#  'aja': 'saja ',
#  'ajaa': 'saja',
#  'ajah': 'saja ',
#  'ajalah': 'saja ',
#  'aje': 'saja ',
#  'ajg': 'anjing',
#  'ajh': 'saja',
#  'ajib': 'hebat',
#  'ajj': 'saja',
#  'ak': 'saya ',
#  'akalakalan': 'akal akalan',
#  'akalakaln': 'akal akalan',
#  'akankena': 'akan kena',
#  'akherat': 'akhirat',
#  'akhi': 'saudara',
#  'akhirny': 'akhirnya',
#  'akhirnyamush': 'akhirnya musuh',
#  'akirnya': 'akhirnya',
#  'akn': 'akan',
#  'akoh': 'saya',
#  'aksiaksi1120aksi112020aksi1120': 'aksi aksi',
#  'akumuslim': 'aku muslim',
#  'akuwa': 'aqua',
#  'alahuakbar': 'allahu akbar',
#  'alallohu': 'alallahu',
#  'alesan': 'alasan ',
#  'alhamdulilah': 'alhamdulillah',
#  'alhamdulillaah': 'alhamdulillah',
#  'alhamdullilah': 'alhamdulillah',
#  'alhmdllh': 'alhamdulillah',
#  'allahuakbar': 'allahu akbar',
#  'allahughayatuna': 'allahu ghayatuna',
#  'alloh': 'allah',
#  'allohu': 'allahu',
#  'alqur': 'alquran',
#  'ama': 'sama ',
#  'amaca': 'ah masa',
#  'amajing': 'luar biasa',
#  'amcaman': 'ancaman',
#  'amiin': 'amin',
#  'aminn': 'amin',
#  'ampe': 'sampai',
#  'amriki': 'amerika',
#  'amuh': 'kamu',
#  'ana': 'saya',
#  'anbiarkekinian': 'biar kekinian',
#  'ancen': 'memang',
#  'ancur': 'hancur ',
#  'ancuur': 'hancur',
#  'ane': 'saya ',
#  'aneh2': 'aneh aneh',
#  'anget': 'hangat ',
#  'angktpn': 'angkatpun',
#  'anjeng': 'anjing ',
#  'anjg': 'anjing',
#  'ank': 'anak ',
#  'anomaly': 'anomali',
#  'antikorupsi': 'anti korupsi',
#  'antum': 'kalian',
#  'anugrah': 'anugerah',
#  'ap': 'apa',
#  'apa2': 'apa apa',
#  'apaapaan': 'apa apaan',
#  'apaapalah': 'apa sajalah',
#  'apah': 'apa ',
#  'apakabar': 'apa kabar',
#  'apalg': 'apa lagi',
#  'apamaunya': 'apa maunya',
#  'apane': 'apanya',
#  'apaoun': 'apapun',
#  'apasih': 'apa sih',
#  'ape': 'apa',
#  'apenista': 'penista',
#  'aph': 'apa',
#  'apk': 'apakah',
#  'aplgi': 'apa lagi',
#  'apo': 'apa ',
#  'apose': 'apa',
#  'apz': 'apa',
#  'aq': 'saya',
#  'aquh': 'aku',
#  'artinx': 'artinya',
#  'asek': 'asik ',
#  'aseng': 'asing',
#  'asew': 'anjing',
#  'asik': 'asyik',
#  'ask': 'tanya',
#  'asline': 'aslinya',
#  'assalamualaikumalhamdulillahhasil': 'assalamualaykum alhamdulillah hasil',
#  'assalamuallaikum': 'assalamualaykum',
#  'asu': 'anjing',
#  'asw': 'anjing',
#  'asyek': 'asyik',
#  'atauatau05atauatau0atauatau0': 'atau',
#  'atauatauatau': 'atau',
#  'atauatauatau201atauatau201atauatauatau201atauatau': 'atau',
#  'atauatauatauatau': 'atau',
#  'atauatauatauatauatauatauatauatauatauatau': 'atau',
#  'atauem': 'atau',
#  'atauhr': 'atau',
#  'ataus': 'atau',
#  'ati': 'hati',
#  'ati2': 'hati-hati ',
#  'atit': 'sakit ',
#  'ato': 'atau',
#  'atribut2': 'atribut atribut',
#  'atu': 'satu ',
#  'atw': 'atau ',
#  'awkeren': 'keren',
#  'awutawutan': 'awut awutan',
#  'aya': 'ada',
#  'ayang': 'sayang ',
#  'ayok': 'ayo',
#  'ayoo': 'ayo',
#  'ayosavepakahok': 'ayo lindungi pak ahok',
#  'ayuk': 'ayo ',
#  'aza': 'saja',
#  'azhan': 'azan',
#  'babeh': 'ayah',
#  'badboy': 'bad boy',
#  'badjingan': 'bajingan',
#  'bae': 'baik ',
#  'bagaimnpun': 'bagaimana',
#  'bagi2': 'bagi bagi',
#  'bagimane': 'bagaimana',
#  'bahwasannya': 'bahwasanya',
#  'bakalan': 'akan ',
#  'balaikota': 'balai kota',
#  'bales': 'balas ',
#  'balikin': 'kembalikan',
#  'baliq': 'balig',
#  'bandarq': 'bandarku',
#  'banding2in': 'membanding bandingkan',
#  'bandingin': 'bandingkan ',
#  'banga': 'bangsa',
#  'banged': 'banget',
#  'bangen': 'banget',
#  'bangett': 'sangat ',
#  'bangettt': 'banget',
#  'bangke': 'bangkai',
#  'bangsag': 'bangsat',
#  'bangst': 'bangsat',
#  'bantuk': 'bentuk',
#  'banun': 'bangun',
#  'banyak2': 'perbanyak',
#  'banyakin': 'perbanyak ',
#  'bapake': 'ayahnya',
#  'baper': 'bawa perasaan',
#  'baryaw': 'sabar ya',
#  'baryw': 'sabar ya',
#  'baso': 'bakso ',
#  'basukibtp': 'basuki tjahaja purnama',
#  'basukigameover': 'basuki kalah',
#  'bat': 'banget',
#  'bauu': 'bau',
#  'bawak': 'bawa',
#  'bay': 'selamat tinggal',
#  'bayangin': 'bayangkan',
#  'bayaranatausuruhan': 'bayaran atau suruhan',
#  'bbrapa': 'beberapa',
#  'bbrp': 'beberapa ',
#  'bc': 'baca ',
#  'bct': 'bicara ',
#  'bda': 'beda',
#  'bdan': 'badan ',
#  'bdg': 'bandung ',
#  'bdn': 'badan ',
#  'becanda': 'bercanda ',
#  'bedoa': 'berdoa',
#  'bedua': 'berdua ',
#  'bege': 'bego',
#  'bejad': 'bejat',
#  'bekel': 'bekal ',
#  'bekingin': 'lindungi',
#  'belaislambelaislambelaislam': 'bela islam',
#  'belaquran': 'bela alquran',
#  'beliin': 'belikan',
#  'belom': 'belum ',
#  'belon': 'belum ',
#  'benar2': 'benar benar',
#  'bener': 'benar ',
#  'bener2': 'benar-benar ',
#  'beneran': 'benar ',
#  'berantem': 'bertengkar ',
#  'berdo': 'berdoa',
#  'berenti': 'berhenti ',
#  'berfikir': 'berpikir',
#  'bergengam': 'bergenggam',
#  'bergoncang': 'berguncang',
#  'berindak': 'bertindak',
#  'beritadan': 'berita dan',
#  'beritain': 'memberitakan',
#  'beritany': 'beritanya',
#  'beritaterkini': 'berita kini',
#  'berkacaberkacanya': 'berkaca kaca',
#  'berrti': 'berarti',
#  'bersyukrlah': 'bersyukurlah',
#  'beruk2': 'beruk beruk',
#  'besoq': 'besok',
#  'bet': 'banget',
#  'bete': 'sebal ',
#  'betulin': 'betulkan',
#  'beud': 'banget',
#  'beut': 'banget',
#  'bg': 'bagi ',
#  'bgd': 'sangat ',
#  'bgerak': 'bergerak',
#  'bget': 'sangat ',
#  'bgi': 'bagi',
#  'bgini': 'begini ',
#  'bgitu': 'begitu ',
#  'bgks': 'bungkus ',
#  'bgm': 'bagaimana ',
#  'bgmn': 'bagaimana ',
#  'bgmna': 'bagaimana',
#  'bgn': 'bangun ',
#  'bgni': 'begini ',
#  'bgntdr': 'bangun tidur ',
#  'bgs': 'bagus ',
#  'bgst': 'bangsat',
#  'bgt': 'sangat ',
#  'bgtu': 'begitu ',
#  'bgus': 'bagus ',
#  'bhay': 'selamat tinggal',
#  'bhinekaan': 'bhineka',
#  'bhinneka': 'bhineka',
#  'bhkan': 'bahkan',
#  'bhn': 'bahan ',
#  'bhong': 'bohong',
#  'bhs': 'bahas ',
#  'bhw': 'bahwa ',
#  'bhwa': 'bahwa',
#  'bhy': 'bahaya ',
#  'biarin': 'biarkan',
#  'biarpn': 'biarpun',
#  'bijimane': 'bagaimana',
#  'bisenye': 'bisanya',
#  'bistu': 'habis itu',
#  'bisya': 'bisa',
#  'biza': 'bisa',
#  'bj': 'baju ',
#  'bju': 'baju ',
#  'bk': 'buku ',
#  'bkan': 'bukan ',
#  'bkap': 'ayah',
#  'bkin': 'bikin ',
#  'bkl': 'bakal ',
#  'bkn': 'bukan ',
#  'bkna': 'bukannya',
#  'bkp': 'ayah',
#  'bkr': 'bakar ',
#  'bks': 'bungkus ',
#  'bl': 'beli ',
#  'blajar': 'belajar ',
#  'blakan': 'blak',
#  'blg': 'bilang ',
#  'blh': 'boleh ',
#  'bli': 'beli ',
#  'blik': 'balik ',
#  'blingsatanya': 'belingsatan',
#  'bljr': 'belajar ',
#  'blk': 'balik ',
#  'blkg': 'belakang ',
#  'blkng': 'belakang ',
#  'blkngny': 'belakangnya ',
#  'blm': 'belum ',
#  'bln': 'bulan ',
#  'blng': 'bilang ',
#  'blngn': 'bilang ',
#  'blom': 'belum ',
#  'blon': 'belum',
#  'bloon': 'belum',
#  'bls': 'balas ',
#  'blum': 'belum ',
#  'blusukan': 'blusuk',
#  'bndg': 'bandung ',
#  'bndr': 'bandar ',
#  'bner': 'benar ',
#  'bneran': 'benar ',
#  'bnget': 'sangat ',
#  'bngks': 'bungkus ',
#  'bngng': 'bingung ',
#  'bngsa': 'bangsa',
#  'bngt': 'sangat ',
#  'bngun': 'bangun ',
#  'bnr': 'benar ',
#  'bnrbnr': 'benar-benar ',
#  'bnrn': 'benar ',
#  'bntar': 'sebentar ',
#  'bntr': 'sebentar',
#  'bnyak': 'banyak ',
#  'bnyk': 'banyak ',
#  'bnykny': 'banyaknya ',
#  'bobo': 'tidur ',
#  'bobok': 'tidur ',
#  'bodo': 'bodoh',
#  'bokap': 'ayah ',
#  'bokaps': 'ayah',
#  'bokapz': 'ayah',
#  'bole': 'boleh ',
#  'boong': 'bohong ',
#  'bosen': 'bosan ',
#  'boskuh': 'bosku',
#  'boten': 'tidak',
#  'bozen': 'bosan',
#  'bozn': 'bosan',
#  'bp': 'bapak',
#  'bpak': 'bapak',
#  'bpk': 'bapak ',
#  'br': 'baru',
#  'brani': 'berani ',
#  'brantas': 'berantas',
#  'brapa': 'berapa ',
#  'brarti': 'berarti ',
#  'brasa': 'berasa ',
#  'bravoo': 'bravo',
#  'breake': 'istirahat',
#  'breaking': 'istirahat',
#  'brengsek': 'berengsek',
#  'brg': 'barang ',
#  'brgkt': 'berangkat ',
#  'brharap': 'berharap',
#  'brhsl': 'berhasil ',
#  'brikut': 'berikut',
#  'bringas': 'beringas',
#  'brisik': 'berisik',
#  'brjln': 'berjalan ',
#  'brjuang': 'berjuang',
#  'brkeliaran': 'berkeliaran',
#  'brkfst': 'breakfast ',
#  'brkpntingan': 'berkepentingan',
#  'brkumandang': 'berkumandang',
#  'brmslh': 'bermasalah ',
#  'brngkt': 'berangkat ',
#  'brp': 'berapa ',
#  'brpa': 'berapa ',
#  'brpedoman': 'berpedoman',
#  'brrti': 'berarti ',
#  'brs': 'beres ',
#  'brsal': 'berasal',
#  'brsama': 'bersama',
#  'brsamamu': 'bersamamu',
#  'brshbt': 'bersahabat ',
#  'brsm': 'bersama ',
#  'brtahan': 'bertahan',
#  'brthn': 'bertahan ',
#  'brtmn': 'berteman ',
#  'bru': 'baru ',
#  'bruh': 'buruh',
#  'bryaw': 'sabar ya',
#  'bryw': 'sabar ya',
#  'bs': 'bisa',
#  'bsa': 'bisa',
#  'bsk': 'besok',
#  'bsok': 'besok ',
#  'bsoq': 'besok',
#  'bsr': 'besar ',
#  'bte': 'bosan',
#  'btg': 'batang ',
#  'bth': 'butuh ',
#  'btl': 'betul ',
#  'btul': 'betul ',
#  'btull': 'betul',
#  'buad': 'buat ',
#  'buatapa': 'buat apa',
#  'buatin': 'buatkan ',
#  'bubarin': 'bubarkan',
#  'bukabukaan': 'buka bukaan',
#  'bukane': 'bukannya',
#  'bukn': 'bukan',
#  'buktiin': 'buktikan',
#  'buktikan': 'buktikan',
#  'buktikqn': 'buktikan',
#  'bul': 'kibul',
#  'bulshit': 'kibul',
#  'buryam': 'bubur ayam',
#  'buzer': 'buzzer',
#  'buzzerahoaxsebarkanhoax': 'buzzer ahok sebar hoaks',
#  'buzzerbuzzernya': 'buzzer buzzernya',
#  'bw': 'bawa ',
#  'bwa': 'bawa ',
#  'bwaanx': 'bawaan',
#  'bwh': 'bawah ',
#  'bwt': 'buat ',
#  'byak': 'banyak',
#  'byk': 'banyak ',
#  'bynk': 'banyak ',
#  'byr': 'bayar ',
#  'bzen': 'bosan',
#  'bzn': 'bosan',
#  'cabut': 'pergi',
#  'cagubnya': 'calon gubernurnya',
#  'cahya': 'cahaya',
#  'caiank': 'sayang',
#  'caiyo': 'semangat',
#  'cakep': 'cakap ',
#  'cantek': 'cantik',
#  'capek': 'capai ',
#  'caturx': 'catur',
#  'cayo': 'semangat',
#  'cb': 'coba ',
#  'cecunguk2nya': 'cecunguk cecunguknya',
#  'ceheheheh': 'hehe',
#  'cekola': 'sekolah',
#  'cekolah': 'sekolah',
#  'celalaw': 'selalu',
#  'celalu': 'selalu',
#  'cemen': 'takut',
#  'cemplungin': 'mencemplungkan',
#  'cemungudh': 'semangat',
#  'cemungut': 'semangat',
#  'cemunguth': 'semangat',
#  'centuryataumuniratauhambalang': 'century munir atau hambalang',
#  'cepat2': 'cepat cepat',
#  'cepet': 'cepat ',
#  'ceplas': 'ceplos',
#  'ceppat': 'cepat',
#  'cewe': 'cewek ',
#  'ciamik': 'indah',
#  'ciap': 'siap',
#  'ciayou': 'semangat',
#  'cibuq': 'sibuk',
#  'cie': 'wah',
#  'ciee': 'wah',
#  'cini': 'sini',
#  'cino': 'cina',
#  'citizens': 'warga kota',
#  'ciyan': 'kasihan',
#  'ciye': 'wah',
#  'ciyus': 'serius',
#  'ckck': 'wkwk',
#  'ckp': 'cukup ',
#  'ckrg': 'sekarang ',
#  'ckup': 'cukup ',
#  'cling': 'bersih',
#  'cll': 'selalu',
#  'cllu': 'selalu',
#  'cllw': 'selalu',
#  'cm': 'cuma ',
#  'cma': 'cuma ',
#  'cman': 'hanya ',
#  'cmn': 'hanya ',
#  'cmpk': 'cempaka ',
#  'col': 'keren',
#  'compares': 'membandingkan',
#  'congrats': 'selamat',
#  'congratulation': 'selamat',
#  'corruptions': 'korupsi',
#  'corruptors': 'koruptor',
#  'cowo': 'cowok ',
#  'coz': 'soalnya',
#  'cpat': 'cepat ',
#  'cpe': 'capek',
#  'cpee': 'capek',
#  'cpet': 'cepat ',
#  'cpt': 'cepat ',
#  'cptn': 'cepatan ',
#  'crt': 'cerita ',
#  'crying': 'menangis',
#  'cs': 'rekan',
#  'cth': 'contoh ',
#  'cukupsatuputaran': 'cukup satu putaran',
#  'cuman': 'hanya',
#  'cw': 'cewek ',
#  'cwe': 'cewek ',
#  'cwo': 'cowok ',
#  'd': 'di',
#  'da': 'dan',
#  'dah': 'sudah',
#  'dalah': 'adalah',
#  'dalem': 'dalam ',
#  'dann': 'dan',
#  'dapa': 'ada apa',
#  'dapah': 'ada apa',
#  'dapet': 'dapat ',
#  'dapetin': 'mendapatkan ',
#  'daripaddatidda': 'dari pada tidak',
#  'datangin': 'mendatangi',
#  'dateng': 'datang ',
#  'daut': 'daud',
#  'dblg': 'dibilang ',
#  'dblkng': 'dibelakang ',
#  'dbls': 'dibalas ',
#  'dbwt': 'dibuat ',
#  'dbyr': 'dibayar ',
#  'ddpn': 'di depan',
#  'dduk': 'duduk',
#  'de': 'deh ',
#  'demen': 'suka ',
#  'democrazy': 'demokrasi gila',
#  'demodemo': 'demo demo',
#  'demodemonov': 'demo november',
#  'denger': 'dengar ',
#  'dengn': 'dengan',
#  'depa': 'depan',
#  'des': 'desember',
#  'dewadewa': 'dewa dewa',
#  'dftr': 'daftar',
#  'dg': 'dengan ',
#  'dgn': 'dengan ',
#  'dgr': 'dengar ',
#  'dgrn': 'dengarin ',
#  'dh': 'sudah',
#  'dhewan': 'dewan',
#  'diaa': 'dia',
#  'diajakin': 'diajak',
#  'dianutny': 'dianutnya',
#  'diapain': 'diapakan',
#  'dibelakanghari': 'di belakang hari',
#  'dibiarin': 'dibiarkan',
#  'dibobongin': 'dibodohi',
#  'dibodohin': 'dibodohi',
#  'dibohongin': 'dibohongi',
#  'dibohonginataudibodohin': 'dibohongi atau dibodohi',
#  'diboongin': 'dibohongi',
#  'dibuatx': 'dibuatnya',
#  'dibudigunawankan': 'di budi gunawankan',
#  'dicuekin': 'dicueki',
#  'didenger': 'didengar ',
#  'didengerin': 'didengarkan ',
#  'didiemin': 'didiamkan',
#  'didlam': 'di dalam',
#  'didzalimi': 'dizalimi',
#  'die': 'dia',
#  'diem': 'diam ',
#  'diem2': 'diam diam',
#  'digembosin': 'digembosi',
#  'diginiin': 'dibeginikan',
#  'dijadiin': 'dijadikan ',
#  'dijatohin': 'dijatuhi',
#  'dijdkn': 'dijadikan',
#  'dikenyataanya': 'pada kenyataannya',
#  'dikirain': 'dikiranya',
#  'dikit': 'sedikit ',
#  'dimance': 'dimana',
#  'dimandose': 'dimana',
#  'dimans': 'dimana',
#  'dimonitoring': 'dipantau',
#  'dinaikin': 'dinaiki',
#  'dinegri': 'di negeri',
#  'dipake': 'dipakai ',
#  'dipemjara': 'di penjara',
#  'diperes': 'diperas',
#  'dipikirin': 'dipikirkan',
#  'dipilkada': 'di pilkada',
#  'diprose': 'diproses',
#  'dirix': 'dirinya',
#  'dirmh': 'di rumah ',
#  'disalahgunakan': 'disalah gunakan',
#  'disamarinda': 'di samarinda',
#  'disewotin': 'disewoti',
#  'disumpahdisumpahin': 'disumpahi',
#  'ditemenin': 'ditemani ',
#  'ditentukn': 'ditentukan',
#  'ditetapknnya': 'ditetapkan',
#  'ditrsangkakan': 'ditersangkakan',
#  'dittapkn': 'ditetapkan',
#  'diyem': 'diam',
#  'dizhalimi': 'dizalimi',
#  'dizholimi': 'dizalimi',
#  'dizolimi': 'dizalimi',
#  'djakarta': 'di jakarta',
#  'djasatuputaran': 'di satu putaran',
#  'djkt': 'di jakarta ',
#  'djl': 'di jalan ',
#  'djln': 'di jalan ',
#  'djmin': 'dijamin',
#  'dkat': 'dekat ',
#  'dket': 'dekat ',
#  'dkijakarta': 'dki jakarta',
#  'dkls': 'di kelas ',
#  'dkmps': 'di kampus ',
#  'dkmr': 'di kamar ',
#  'dkntr': 'di kantor ',
#  'dksh': 'dikasih ',
#  'dkt': 'dekat ',
#  'dl': 'dulu ',
#  'dlm': 'dalam ',
#  'dlmnya': 'dalamnya',
#  'dlrng': 'dilarang ',
#  'dlu': 'dulu ',
#  'dluan': 'duluan ',
#  'dmana': 'dimana ',
#  'dmkn': 'dimakan ',
#  'dmn': 'dimana ',
#  'dmna': 'dimana ',
#  'dmnmn': 'dimana-mana ',
#  'dmny': 'dimananya ',
#  'dn': 'dan',
#  'dng': 'dengan ',
#  'dngan': 'dengan',
#  'dngar': 'dengar ',
#  'dnger': 'dengar ',
#  'dngerin': 'dengar ',
#  'dngn': 'dengan ',
#  'dngr': 'dengar ',
#  'doain': 'doakan',
#  'doank': 'saja ',
#  'doi': 'dia',
#  'dongok': 'dungu',
#  'donlot': 'download ',
#  'dont': 'do not',
#  'doyan': 'suka ',
#  'dp': 'uang muka',
#  'dpan': 'depan ',
#  'dpet': 'dapat ',
#  'dpk': 'depok ',
#  'dpkrkn': 'dipikirkan ',
#  'dpn': 'depan ',
#  'dpnrmh': 'depan rumah ',
#  'dpt': 'dapat ',
#  'dr': 'dari ',
#  'drg': 'dokter gigi ',
#  'drh': 'darah ',
#  'dri': 'dari ',
#  'drmh': 'di rumah ',
#  'drmn': 'darimana ',
#  'drpd': 'daripada ',
#  'drtd': 'dari tadi',
#  'drumah': 'di rumah',
#  'dsar': 'dasar',
#  'dsb': 'dan sebagainya',
#  'dsblh': 'di sebelah',
#  'dsini': 'disini ',
#  'dsklh': 'di sekolah',
#  'dsni': 'di sini',
#  'dsnii': 'di sini',
#  'dst': 'dan seterusnya',
#  'dtetapak': 'ditetapkan',
#  'dtg': 'datang ',
#  'dtgn': 'datang',
#  'dtgny': 'datangnya ',
#  'dtmbh': 'ditambah ',
#  'dtmpt': 'di tempat',
#  'dtng': 'datang ',
#  'dttapkn': 'ditetapkan',
#  'dtuntut': 'dituntun',
#  'duabelas': 'dua belas',
#  'duaduanya': 'dua duanya',
#  'duchh': 'aduh',
#  'duh': 'aduh',
#  'duit2': 'duit duit',
#  'dukungahok': 'dukung ahok',
#  'dukungfatwa': 'dukung fatwa',
#  'dukungfatwamui': 'dukung fatwa mui',
#  'duluan': 'lebih dahulu',
#  'duluw': 'dulu',
#  'dunk': 'dong',
#  'durung': 'belum',
#  'dy': 'dia ',
#  'dya': 'dia',
#  'dzolim': 'zalim',
#  'dzolimi': 'dizalimi',
#  'ea': 'ya',
#  'eagles': 'elang',
#  'ealah': 'iyalah',
#  'ech': 'eh',
#  'eehh': 'eh',
#  'egak': 'tidak',
#  'egh': 'eh',
#  'ehh': 'eh',
#  'ekong': 'kakek',
#  'elech': 'alah',
#  'elee': 'alah',
#  'elektibilitas': 'elektabilitas',
#  'elit': 'elite',
#  'elo': 'kamu ',
#  'elu': 'kamu',
#  'eman': 'sayang',
#  'emang': 'memang ',
#  'emangnya': 'memangnya ',
#  'emank': 'memang ',
#  'emg': 'memang',
#  'emng': 'memang ',
#  'en': 'dan',
#  'ending': 'akhir',
#  'endingnya': 'akhirnya',
#  'engga': 'tidak ',
#  'enggak': 'tidak ',
#  'enjarakanahok': 'penjarakan ahok',
#  'enk': 'enak ',
#  'entar': 'nanti ',
#  'ente': 'anda ',
#  'entee': 'kamu',
#  'erti': 'mengerti',
#  'esbeye': 'susilo bambang yudhoyono',
#  'eskrim': 'es krim',
#  'eteb': 'bosan',
#  'everythings': 'segalanya',
#  'faham': 'paham ',
#  'fanati': 'fanatik',
#  'fb': 'facebook ',
#  'fcked': 'fuck',
#  'fears': 'fear',
#  'feb': 'februari',
#  'fikir': 'pikir',
#  'fikiran': 'pikiran',
#  'finah': 'fitnah',
#  'follback': 'ikuti',
#  'follbek': 'ikuti',
#  'followback': 'ikuti',
#  'follower': 'pengikut',
#  'followers': 'pengikut',
#  'freeahok': 'free ahok',
#  'futures': 'masa depan',
#  'g': 'tidak',
#  'ga': 'tidak',
#  'gaada': 'tidak ada',
#  'gabakal': 'tidak akan',
#  'gaberani': 'tidak berani',
#  'gabisa': 'tidak bisa',
#  'gaboleh': 'tidak boleh',
#  'gabut': 'menganggur',
#  'gada': 'tidak ada',
#  'gaenak': 'tidak enak',
#  'gaikut': 'tidak ikut',
#  'gajadi': 'tidak jadi',
#  'gajelas': 'tidak jelas',
#  'gak': 'tidak',
#  'gakuat': 'tidak kuat',
#  'gakz': 'tidak',
#  'galak2': 'galak galak',
#  'galo': 'galau ',
#  'gamasuk': 'tidak masuk',
#  'gamau': 'tidak mau',
#  'ganbate': 'semangat',
#  'ganyangahok': 'ganyang ahok',
#  'ganyangcina': 'ganyang cina',
#  'gapake': 'tidak pakai',
#  'gapapa': 'tidak apa-apa',
#  'gapapalah': 'tidak apalah',
#  'gapape': 'tidak apa',
#  'gapedulisamastatus': 'tidak peduli dengan status',
#  'gapernah': 'tidak pernah',
#  'gapunya': 'tidak punya',
#  'gara2': 'gara gara',
#  'garangangarangan': 'garang',
#  'garem': 'garam ',
#  'gasuka': 'tidak suka',
#  'gatau': 'tidak tahu',
#  'gataw': 'tidak tahu',
#  'gatel': 'gatal ',
#  'gausah': 'tidak usah',
#  'gawe': 'kerja ',
#  'gbr': 'gambar ',
#  'gdg': 'gudang ',
#  'gece': 'gerak cepat',
#  'gelaja': 'gejala',
#  'gelarperkarasudahdiumumkan': 'gelar perkara sudah umum',
#  'gelik': 'geli',
#  'gelo': 'gila',
#  'gemes': 'gemas',
#  'gengges': 'ganggu',
#  'genks': 'geng',
#  'gera': 'gerak',
#  'gerja': 'gereja',
#  'ggl': 'gagal',
#  'ghiy': 'lagi',
#  'gi': 'lagi',
#  'gilak': 'gila ',
#  'gile': 'gila ',
#  'gilla': 'gila',
#  'gimana': 'bagaimana',
#  'gimanapun': 'bagaimanapun',
#  'gin': 'begini',
#  'ginian': 'beginian',
#  'gitu': 'begitu ',
#  'gituan': 'begitu ',
#  'gituh': 'begitu ',
#  'gk': 'tidak',
#  'gmana': 'bagaimana ',
#  'gmbr': 'gambar ',
#  'gmn': 'bagaimana ',
#  'gmna': 'bagaimana ',
#  'gmpg': 'gampang ',
#  'gmpng': 'gampang ',
#  'gni': 'begini ',
#  'gnti': 'ganti ',
#  'goblog': 'goblok',
#  'goblog2in': 'goblok goblokin',
#  'going': 'pergi',
#  'gonna': 'pergi',
#  'gosipin': 'menggosipkan',
#  'gov': 'gubernur',
#  'governo': 'gubernur',
#  'governoor': 'gubernur',
#  'governor': 'gubernur',
#  'governour': 'gubernur',
#  'govt': 'pemerintah',
#  'goyangin': 'goyangkan',
#  'gpl': 'tidak pakai lama',
#  'gpny': 'tidak punya',
#  'gpp': 'tidak apa apa',
#  'gprnh': 'tidak pernah',
#  'gr': 'gede rasa',
#  'gr2': 'gara-gara ',
#  'gratisan': 'gratis ',
#  'gregetan': 'geregetan',
#  'gt': 'begitu ',
#  'gtu': 'begitu ',
#  'gtw': 'tidak tahu',
#  'gua': 'saya ',
#  'gub': 'gubernur',
#  'gubatauwalkot': 'gubernur atau walikota',
#  'gubenur': 'gubernur',
#  'guberenur': 'gubernur',
#  'guemewek': 'gue mewek',
#  'guoblog': 'goblok',
#  'gurbenur': 'gubernur',
#  'guwe': 'gue',
#  'gw': 'saya',
#  'gwe': 'gue',
#  'gws': 'get well soon',
#  'gx': 'tidak',
#  'ha': 'apa',
#  'habaib': 'habib',
#  'hacur': 'hancur',
#  'hadeh': 'aduh ',
#  'hadeuh': 'aduh',
#  'hahaha': 'haha',
#  'hahahahaha': 'haha',
#  'hapal': 'hafal',
#  'hape': 'telepon genggam',
#  'happening': 'terjadi',
#  'haq': 'hak',
#  'haqq': 'hakiki ',
#  'hariharimu': 'hari harimu',
#  'harini': 'hari ini',
#  'haritoleransiinternasional': 'hari toleransi internasional',
#  'haritoleransinasional': 'hari toleransi nasional',
#  'hastag': 'tagar',
#  'hastage': 'tagar',
#  'haters': 'hater',
#  'hatinye': 'hatinya',
#  'hbd': 'happy birthday',
#  'hbis': 'habis ',
#  'hbng': 'hubungi ',
#  'hbngn': 'hubungan',
#  'hbs': 'habis ',
#  'hbskn': 'habiskan ',
#  'hdup': 'hidup',
#  'hebatx': 'hebatnya',
#  'helow': 'halo',
#  'hepi': 'senang',
#  'hepihepinya': 'senang senangnya',
#  'hera': 'heran',
#  'hestag': 'tagar',
#  'hestagnya': 'tagarnya',
#  'hesteg': 'tagar',
#  'hestek': 'tagar',
#  'hgga': 'hingga',
#  'hha': 'haha',
#  'hhaaa': 'haha',
#  'hidupgwselo': 'hidup saya santai',
#  'hilangin': 'hilangkan',
#  'hkm': 'hukum',
#  'hkum': 'hukum',
#  'hlg': 'hilang ',
#  'hlm': 'halaman ',
#  'hlmn': 'halaman ',
#  'hmm': 'hem',
#  'hny': 'hanya ',
#  'hnya': 'hanya',
#  'hoak': 'hoaks',
#  'hoaker': 'penyebar hoaks',
#  'hoakers': 'penyebar hoaks',
#  'hog': 'ahok',
#  'hok': 'ahok',
#  'hopeless': 'putus asa',
#  'hormatin': 'hormati',
#  'hotels': 'hotel',
#  'hr': 'hari ',
#  'hrapan': 'harapan',
#  'hrg': 'harga ',
#  'hrgny': 'harganya ',
#  'hri': 'hari ',
#  'hrs': 'harus ',
#  'hrsny': 'harusnya ',
#  'hrsnya': 'seharusnya',
#  'hrus': 'harus ',
#  'hsl': 'hasil',
#  'hti': 'hati ',
#  'huah': 'wah',
#  'huakbar': 'allahu akbar',
#  'hub': 'hubung',
#  'hubunganya': 'hubungannya',
#  'huehue': 'hehe',
#  'hukumanny': 'hukumannya',
#  'hums': 'rumah',
#  'humz': 'rumah',
#  'huum': 'iya',
#  'huwallohu': 'allahu',
#  'hy': 'hanya',
#  'idelete': 'hapus',
#  'idup': 'hidup',
#  'igat': 'ingat',
#  'ihlas': 'ikhlas',
#  'ijo': 'hijau',
#  'iket': 'ikat',
#  'iki': 'ini',
#  'iklas': 'ikhlas',
#  'iku': 'ikut',
#  'ikutikutan': 'ikut ikutan',
#  'ikutin': 'ikuti',
#  'ilah': 'lah',
#  'ilang': 'hilang',
#  'ilangnya': 'hilangnya',
#  'imbau': 'himbau',
#  'imembela': 'saya membela',
#  'imwith': 'saya dengan',
#  'imwithahok': 'saya dengan ahok',
#  'ind': 'indonesia',
#  'indakk': 'tidak',
#  'independen': 'bebas',
#  'indo': 'indonesia',
#  'indonesian': 'indonesia',
#  'inget': 'ingat ',
#  'ingetin': 'ingatkan ',
#  'ingnikan': 'menginginkan',
#  'ingt': 'ingat ',
#  'inibarujakarta': 'ini baru jakarta',
#  'inideh': 'ini deh',
#  'innocense': 'tidak bersalah',
#  'inoleran': 'tidak toleran',
#  'insallah': 'insyaallah',
#  'insha': 'insya',
#  'insyaa': 'insya',
#  'insyaallah': 'insyaallah',
#  'insyaalloh': 'insyaallah',
#  'insyallah': 'insyaallah',
#  'internationally': 'international',
#  'isa': 'bisa',
#  'iso': 'bisa',
#  ...}

# %%
#rename column
# df=df[['reviewText','labelEmotions']]
# df=df.rename(columns={"reviewText": "text", "labelEmotions": "label"})

df=df[['Customer Review','Emotion']]
df=df.rename(columns={"Customer Review": "text", "Emotion": "label"})
df.head()
# Out:
#                                                 text  label
# 0  Alhamdulillah berfungsi dengan baik. Packaging...  Happy
# 1  barang bagus dan respon cepat, harga bersaing ...  Happy
# 2  barang bagus, berfungsi dengan baik, seler ram...  Happy
# 3  bagus sesuai harapan penjual nya juga ramah. t...  Happy
# 4  Barang Bagus, pengemasan Aman, dapat Berfungsi...  Happy

# %%
import string
import regex as re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
def process_cleaning(text):

    # remove emoji spesifik, angka, url dulu
    text_cleaning_re = r"rt|url|[^\w\s]|'|nbsp|https\S+|[0-9]+"
    text_sub = re.sub(text_cleaning_re, ' ', str(text))

    # Remove strip / trims
    text_strip = text_sub.strip()

    # remove punctutation/simbolll
    translator = str.maketrans('', '', string.punctuation)
    text_no_punct = text_strip.translate(translator)

    # Lower Case
    text_lower = text_no_punct.casefold()

    # tokenize
    text_token_stan = word_tokenize(text_lower)

    word_dict = []
    for word in text_token_stan:
        word_dict.append(kamus_alay_dict.get(word, word))
    tokens = " ".join(word_dict)

    # tambah kata singkatan =
    more_stopword = ["sih","nya"]

    # menampung stopword ke variabel untuk jadi operator remove stopword
    stopword_user = StopWordRemoverFactory().get_stop_words() + more_stopword
    # stopword_user = StopWordRemoverFactory().get_stop_words()

    # alternatif untuk perbaiki akurasi
    token_new = word_tokenize(tokens)
    filter_new = []
    filter_new2 = [word.strip() for word in token_new]
    filter_new = [word for word in filter_new2 if not word in stopword_user]
    tokens = " ".join(filter_new)

    return tokens

# %%
import numpy as np
import string

# data['cleaned without dict'] = data['Customer Review'].apply(process_cleaning2)
df['text'] = df['text'].apply(process_cleaning)
# print(list(data["processed_cleaning"]))

# x_cleaned = data['cleaned']
x_cleaned = df['text']
# x_cleaned2 = data['cleaned without dict']
# x_cleaned = data["cleaned"].values
df.head(10)
# Out:
#                                                 text  label
# 0  alhamdulillah berfungsi packaging aman respon ...  Happy
# 1           barang bagus respon cepat harga bersaing  Happy
# 2  barang bagus berfungsi seler ramah pengiriman ...  Happy
# 3  bagus sesuai harapan penjual ramah terima kasi...  Happy
# 4             barang bagus pengemasan aman berfungsi  Happy
# 5                          barang bagus seller ramah  Happy
# 6                                  mantap paten joss  Happy
# 7  works fine respon seller cepat barang berfungs...  Happy
# 8  barang bagus segel utuh original berfungsi sel...  Happy
# 9               barang berfungsi bagus lampu birunya  Happy

# %%
from sklearn.preprocessing import LabelEncoder
from collections import Counter

# %%
#encode label
# def label2id (row):
#   if row['label'] == "Sadness":
#     return 0
#   if row['label'] == "Anger" :
#     return 1
#   if row['label'] == "Love" :
#     return 2
#   if row['label'] == "Fear":
#     return 3
#   if row['label'] == "Happy":
#     return 4

print(Counter(df['label']))
label_encoder = LabelEncoder()
df['label'] = label_encoder.fit_transform(df['label'])
# # print(data["emotion"].value_counts())
print(Counter(df['label']))
y_replaced = df['label']
print(y_replaced)
# Out:
# Counter({'Happy': 1770, 'Sadness': 1202, 'Fear': 920, 'Love': 809, 'Anger': 699})
# Counter({2: 1770, 4: 1202, 1: 920, 3: 809, 0: 699})
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 5395    3
# 5396    3
# 5397    2
# 5398    2
# 5399    3
# Name: label, Length: 5400, dtype: int64

# %%
df.head(5)
# Out:
#                                                 text  label
# 0  alhamdulillah berfungsi packaging aman respon ...      2
# 1           barang bagus respon cepat harga bersaing      2
# 2  barang bagus berfungsi seler ramah pengiriman ...      2
# 3  bagus sesuai harapan penjual ramah terima kasi...      2
# 4             barang bagus pengemasan aman berfungsi      2

# %%
from sklearn.model_selection import train_test_split

# x_train, x_test, y_train, y_test = train_test_split(x_cleaned, y_replaced, test_size=0.2, random_state=225)

# %%
train_valid_ratio = 0.80
train_test_ratio = 0.20

#train test split
df_train, df_test = train_test_split(df, test_size = train_test_ratio, random_state = 42)
print("Train Shape",df_train.shape)
print("Test Shape",df_test.shape)

print(df_train)
#train valid split
# df_train, df_valid = train_test_split(df_train, train_size = train_valid_ratio, random_state = 42)
# print("Train Shape",df_train.shape)
# print("Valid Shape",df_valid.shape)
# Out:
# Train Shape (4320, 2)
# Test Shape (1080, 2)
#                                                    text  label
# 4148  barangnya terima pecah sudut posisi dilapis ga...      4
# 2809  masker bagus bahannya nyaman gampang kusut pes...      4
# 621   produk sesuai pengiriman cepat harganya ribu p...      2
# 566                   dendeng daging sapi asli campuran      1
# 1957                                    mantap pokoknya      3
# ...                                                 ...    ...
# 3772  teliti kiraan produk asli ex australia ex kalb...      1
# 5191  barangnya bagus tebal best deal kemarin mama s...      3
# 5226         kualitas produk bagus respon penjual ramah      2
# 5390  sip paket selamat semoga berfungsi terima kasi...      2
# 860                       barang sesuai pc liter kecewa      4
#
# [4320 rows x 2 columns]

# %%
display(df_train)
# Out:
#                                                    text  label
# 0     produk sesuai pengiriman cepat harganya ribu p...      2
# 1     mantap murah terima kasih kak terima kasih aba...      2
# 2          respon cepat packing oke rapi orderan sesuai      2
# 3     barang sesuai ukuran mesin cuci tabung pas ter...      2
# 4     aplikator mudah dipakai desainnya lucu warnany...      2
# ...                                                 ...    ...
# 4315                                              nyala      1
# 4316  beli celana hitam grey merah muda ukuran beda ...      1
# 4317                            bangkai mati semuanyaaa      1
# 4318  butuh cepat kirim respon jual amanah brather j...      1
# 4319  teliti kiraan produk asli ex australia ex kalb...      1
#
# [4320 rows x 2 columns]

# %%
# df=df.rename(columns={"label": "emotions", "labelEncoded": "label"})
print(df.head())
# label_reference=df[['emotions','label']].copy().drop_duplicates()
# print(df[['emotions','label']].copy().drop_duplicates())
# print(df['Emotion'].copy().drop_duplicates())
# print(df['label'].copy().drop_duplicates())
# print(df.rename(columns={'label': 'emotions', 'labelEncoded': 'label'}))
# print(df['label'].drop_duplicates())
print(df['label'])
# Out:
#                                                 text  label
# 0  alhamdulillah berfungsi packaging aman respon ...      2
# 1           barang bagus respon cepat harga bersaing      2
# 2  barang bagus berfungsi seler ramah pengiriman ...      2
# 3  bagus sesuai harapan penjual ramah terima kasi...      2
# 4             barang bagus pengemasan aman berfungsi      2
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 5395    3
# 5396    3
# 5397    2
# 5398    2
# 5399    3
# Name: label, Length: 5400, dtype: int64

# %%
#prepare data train and validation
import pandas as pd
df_val = pd.DataFrame()
print(df_val)

# pd.concat(df, ignore_index=True)
# print(range(df['label'].drop_duplicates()))
# df[df['label']]
# print(df[df['label']] == )
print(df_train.shape)
for row in df['label'].drop_duplicates():
  df_val = pd.concat([df_val, df_train.loc[df_train['label']==row]], ignore_index=True)
  # print(df.loc[df['label']==row])
# lanjut develop di sini
# df_train = df[~df.text.isin(df_val.text)].copy()
df_train = df_val
# print(df_val)
print(df_train.shape)
# df_train = df[~df.text.isin(df_val.text)].copy()
# df_train.shape
# print(df_train)
# df_train = df[~df.text.isin(df_val.text)].copy()
# print(df_train.shape)
# # df_train = pd.concat([])
# df_train
# for index,sentence in df[['label']].drop_duplicates().iterrows():
#   # df_val = pd.concat([df_val,df[df.loc['label']==sentence.item()].head(5)])
#   df_val=df_val.append(df[df['label']==sentence.item()].head(5))
#   # df_val=df_val.append(df.loc[df['label']==sentence.item()].head(5))
# df_train = df[~df.text.isin(df_val.text)].copy()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# (4320, 2)
# (4320, 2)

# %%
print(df_train)
# Out:
#                                                    text  label
# 0     produk sesuai pengiriman cepat harganya ribu p...      2
# 1     mantap murah terima kasih kak terima kasih aba...      2
# 2          respon cepat packing oke rapi orderan sesuai      2
# 3     barang sesuai ukuran mesin cuci tabung pas ter...      2
# 4     aplikator mudah dipakai desainnya lucu warnany...      2
# ...                                                 ...    ...
# 4315                                              nyala      1
# 4316  beli celana hitam grey merah muda ukuran beda ...      1
# 4317                            bangkai mati semuanyaaa      1
# 4318  butuh cepat kirim respon jual amanah brather j...      1
# 4319  teliti kiraan produk asli ex australia ex kalb...      1
#
# [4320 rows x 2 columns]

# %%
df_val
# Out:
#                                                    text  label
# 0     produk sesuai pengiriman cepat harganya ribu p...      2
# 1     mantap murah terima kasih kak terima kasih aba...      2
# 2          respon cepat packing oke rapi orderan sesuai      2
# 3     barang sesuai ukuran mesin cuci tabung pas ter...      2
# 4     aplikator mudah dipakai desainnya lucu warnany...      2
# ...                                                 ...    ...
# 4315                                              nyala      1
# 4316  beli celana hitam grey merah muda ukuran beda ...      1
# 4317                            bangkai mati semuanyaaa      1
# 4318  butuh cepat kirim respon jual amanah brather j...      1
# 4319  teliti kiraan produk asli ex australia ex kalb...      1
#
# [4320 rows x 2 columns]

# %%
#convert dataframe to dataset type
dataset_train = Dataset.from_dict(df_train)
dataset_val =  Dataset.from_dict(df_test)
print("Dataset Train : ",dataset_train)
print("Dataset Val : ",dataset_val)
# Out:
# Dataset Train :  Dataset({
#     features: ['text', 'label'],
#     num_rows: 4320
# })
# Dataset Val :  Dataset({
#     features: ['text', 'label'],
#     num_rows: 1080
# })

# %% [markdown]
# #Load Pre-trained Model and Fine Tune

# %%
#konfigurasi penamaan label sesuai dengan kelas emoion yang digunakan
id2label = {
    "0": "Anger",
    "1": "Fear",
    "2": "Happy",
    "3": "Love",
    "4": "Sadness"
  }
label2id= {
    "Anger": 0,
    "Fear": 1,
    "Happy": 2,
    "Love": 3,
    "Sadness": 4
  }

# %%
from sklearn.preprocessing import LabelEncoder
from collections import Counter

# print(Counter(df['label']))
# label_encoder = LabelEncoder()
# df['label'] = label_encoder.fit_transform(df['label'])
# # # print(data["emotion"].value_counts())
# print(Counter(df['label']))
# y_replaced = df['label']
# print(y_replaced)

# %%
# https://huggingface.co/indobenchmark/indobert-lite-base-p2
# https://huggingface.co/ayameRushia/indobert-base-uncased-finetuned-indonlu-smsa
config = AutoConfig.from_pretrained("indolem/indobertweet-base-uncased")
# label_encoder = LabelEncoder()
# print(label_encoder.fit(config))
print(config)

# config.label2id = label2id
# config.id2label = id2label
# config._num_labels = len(label2id)
# print(config.label2id)
# print(config.id2label)
# print(config._num_labels)
# Out:
# BertConfig {
#   "_name_or_path": "indolem/indobertweet-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_ids": 0,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.47.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 31923
# }

# %%
tokenizer = AutoTokenizer.from_pretrained("indolem/indobertweet-base-uncased")
model = AutoModelForSequenceClassification.from_pretrained("indolem/indobertweet-base-uncased",config=config)
model.config
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at indolem/indobertweet-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertConfig {
#   "_attn_implementation_autoset": true,
#   "_name_or_path": "indolem/indobertweet-base-uncased",
#   "_num_labels": 5,
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_ids": 0,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "Anger",
#     "1": "Fear",
#     "2": "Happy",
#     "3": "Love",
#     "4": "Sadness"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "Anger": 0,
#     "Fear": 1,
#     "Happy": 2,
#     "Love": 3,
#     "Sadness": 4
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.47.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 31923
# }

# %%
model.save_pretrained("indobertweet-base-uncased-model")
tokenizer.save_pretrained("indobertweet-base-uncased-model")
# Out:
# ('indobertweet-base-uncased-model\\tokenizer_config.json',
#  'indobertweet-base-uncased-model\\special_tokens_map.json',
#  'indobertweet-base-uncased-model\\vocab.txt',
#  'indobertweet-base-uncased-model\\added_tokens.json',
#  'indobertweet-base-uncased-model\\tokenizer.json')

# %%
tokenizer = AutoTokenizer.from_pretrained("../preprocess/indobertweet-base-uncased-model")
model = AutoModelForSequenceClassification.from_pretrained("../preprocess/indobertweet-base-uncased-model")
model.eval()
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(31923, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=5, bias=True)
# )

# %%
def tokenize_function(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True, max_length=512)

# %%
dataset_train = dataset_train.map(tokenize_function, batched=True)
dataset_val = dataset_val.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/4320 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1080 [00:00<?, ? examples/s]

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='macro')
    acc = accuracy_score(labels, preds)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

# %%
training_args = TrainingArguments("test_trainer", eval_strategy="epoch",per_device_train_batch_size=8,num_train_epochs=8,learning_rate=2e-5,logging_steps=1, report_to="none")
trainer = Trainer(model=model.cuda(), args=training_args, train_dataset=dataset_train, eval_dataset=dataset_val,compute_metrics=compute_metrics)
trainer.train()
# Out:
#     <div>
#
#       <progress value='4320' max='4320' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4320/4320 58:05, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.138800</td>
#       <td>0.927065</td>
#       <td>0.620370</td>
#       <td>0.550013</td>
#       <td>0.610276</td>
#       <td>0.540116</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.413400</td>
#       <td>0.931121</td>
#       <td>0.622222</td>
#       <td>0.599529</td>
#       <td>0.603719</td>
#       <td>0.606051</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.337600</td>
#       <td>0.998913</td>
#       <td>0.635185</td>
#       <td>0.590403</td>
#       <td>0.639203</td>
#       <td>0.586903</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.575400</td>
#       <td>0.988704</td>
#       <td>0.650000</td>
#       <td>0.612942</td>
#       <td>0.624118</td>
#       <td>0.607092</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.267500</td>
#       <td>1.164067</td>
#       <td>0.631481</td>
#       <td>0.592909</td>
#       <td>0.612722</td>
#       <td>0.589072</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.165800</td>
#       <td>1.382699</td>
#       <td>0.633333</td>
#       <td>0.599458</td>
#       <td>0.604035</td>
#       <td>0.598778</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.049000</td>
#       <td>1.548467</td>
#       <td>0.624074</td>
#       <td>0.589344</td>
#       <td>0.593393</td>
#       <td>0.591716</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.096400</td>
#       <td>1.632096</td>
#       <td>0.625000</td>
#       <td>0.587733</td>
#       <td>0.599287</td>
#       <td>0.585175</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=4320, training_loss=0.5033424910296971, metrics={'train_runtime': 3487.9816, 'train_samples_per_second': 9.908, 'train_steps_per_second': 1.239, 'total_flos': 9093363003555840.0, 'train_loss': 0.5033424910296971, 'epoch': 8.0})

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 00:30]
#     </div>
# {'eval_loss': 1.6320959329605103,
#  'eval_accuracy': 0.625,
#  'eval_f1': 0.5877331422754372,
#  'eval_precision': 0.5992867408118567,
#  'eval_recall': 0.5851754932046449,
#  'eval_runtime': 30.8361,
#  'eval_samples_per_second': 35.024,
#  'eval_steps_per_second': 4.378,
#  'epoch': 8.0}

# %%
# trainer.save_model('/content/gdrive/MyDrive/ColabNotebooks/Chatbot/Experimen 3/Model/chatbot_M6')
# trainer.save_model('/content/gdrive/MyDrive/Dataset Model Bert/bert_result')

# %%
#convert dataframe to dataset type
dataset_test= Dataset.from_dict(df_test)
dataset_test = dataset_test.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/1080 [00:00<?, ? examples/s]

# %%
predicted_review = trainer.predict(dataset_test)
raw_pred, _, _ = predicted_review
predclas= np.argmax(raw_pred, axis=1)

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
labels = df_test["label"].unique()
accuracy = accuracy_score(df_test['label'], predclas)
print('Accuracy: ', accuracy * 100)
precision = precision_score(df_test['label'], predclas, average='macro', zero_division=1)
print('Precision: ', precision * 100)
# recall: tp / (tp + fn)
recall = recall_score(df_test['label'], predclas, average='macro', zero_division=1)
print('Recall: ', recall * 100)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(df_test['label'], predclas, average='macro')
print('F1 score: ', f1 * 100)
print('Classification Report:')
print(classification_report(df_test['label'], predclas, labels=labels, digits=4))
cm = confusion_matrix(df_test['label'], predclas, labels=labels)
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax, cmap='Blues', fmt="d")

ax.set_title('Confusion Matrix')

ax.set_xlabel('Predicted Labels')
ax.set_ylabel('True Labels')
# Out:
# Accuracy:  62.5
# Precision:  59.928674081185676
# Recall:  58.51754932046449
# F1 score:  58.773314227543715
# Classification Report:
#               precision    recall  f1-score   support
#
#            2     0.7280    0.7893    0.7574       356
#            4     0.6125    0.5810    0.5963       253
#            1     0.4490    0.5535    0.4958       159
#            3     0.6624    0.6228    0.6420       167
#            0     0.5446    0.3793    0.4472       145
#
#     accuracy                         0.6250      1080
#    macro avg     0.5993    0.5852    0.5877      1080
# weighted avg     0.6251    0.6250    0.6217      1080
# Text(50.722222222222214, 0.5, 'True Labels')
